# %%
import pandas as pd
import numpy as np
main_df = pd.read_csv("survey_responses.csv")
sub_df = pd.read_csv("survey_questions_meta.csv")

# %%
# Check for possible ID columns
print("Main DF Columns:", main_df.columns.tolist())
print("Sub DF Columns:", sub_df.columns.tolist())
# Out:
# Main DF Columns: ['Career', 'Citizenship', 'Nationality', 'Year since Matriculation', 'Year of Study', 'Primary Programme', 'Gender', 'Department', 'Housing Type', 'Q1-How many events have you Volunteered in ?', 'Q2-How many events have you Participated in ?', 'Q3-How many activities are you Interested in ?', 'Q4-How many activities are you Passionate about ?', 'Q5-What are your levels of stress ?', 'Q6-How Satisfied You are with your Student Life ?', 'Q7-How much effort do you make to interact with others ?', 'Q8-About How events are you aware about ?', 'response_id', 'Q9-What is an ideal student life ?']
# ...

# %%
df = pd.merge(main_df, sub_df, on="response_id", how="inner")

# %%
print(df.shape)
df.columns.tolist()
# Out:
# (2958, 67)
# ['Career',
#  'Citizenship',
#  'Nationality',
#  'Year since Matriculation',
#  'Year of Study',
#  'Primary Programme',
#  'Gender',
#  'Department',
#  'Housing Type',
#  'Q1-How many events have you Volunteered in ?',
#  'Q2-How many events have you Participated in ?',
#  'Q3-How many activities are you Interested in ?',
#  'Q4-How many activities are you Passionate about ?',
#  'Q5-What are your levels of stress ?',
#  'Q6-How Satisfied You are with your Student Life ?',
#  'Q7-How much effort do you make to interact with others ?',
#  'Q8-About How events are you aware about ?',
#  'response_id',
#  'Q9-What is an ideal student life ?',
#  'Q1-Volunteered For Animal welfare',
#  'Q1-Volunteered For Arts/Culture/Heritage',
#  'Q1-Volunteered For Children/Youth',
#  'Q1-Volunteered For Community building',
#  'Q1-Volunteered For Diversity & Inclusion',
#  'Q1-Volunteered For Environmental sustainability',
#  'Q1-Volunteered For Families',
# ...

# %%
df.head()
# Out:
#   Career      Citizenship Nationality  Year since Matriculation  \
# 0   UGRD        Foreigner   Indonesia                         2
# 1   UGRD  Country Citizen   Singapore                         1
# 2   UGRD        Foreigner    Malaysia                         2
# 3   UGRD        Foreigner    Malaysia                         2
# 4   UGRD        Foreigner    Viet Nam                         3
#
#    Year of Study        Primary Programme Gender             Department  \
# 0              2      Bachelor of Science      F      School of Science
# 1              1  Bachelor of Engineering      F  School of Engineering
# 2              2      Bachelor of Science      M      School of Science
# 3              2  Bachelor of Engineering      M  School of Engineering
# 4              3  Bachelor of Engineering      F  School of Engineering
#
#     Housing Type  Q1-How many events have you Volunteered in ?  ...  \
# 0     Residences                                             0  ...
# ...

# %%
categorical_col = df.select_dtypes(include=['object']).columns.tolist()
# Filter those that start with 'Q'
categorical_cols = [col for col in categorical_col if col.startswith(('Q1', 'Q2', 'Q3', 'Q4', 'Q5'))]
print("Categorical Columns:", categorical_cols)
# Out:
# Categorical Columns: ['Q1-Volunteered For Animal welfare', 'Q1-Volunteered For Arts/Culture/Heritage', 'Q1-Volunteered For Children/Youth', 'Q1-Volunteered For Community building', 'Q1-Volunteered For Diversity & Inclusion', 'Q1-Volunteered For Environmental sustainability', 'Q1-Volunteered For Families', 'Q1-Volunteered For Health/Well-being (e.g mental health)', 'Q1-Volunteered For Seniors', 'Q1-Volunteered For Poverty reduction', 'Q1-Volunteered For Education', 'Q1-Volunteered For Others', 'Q2-Participated in Societies and Interest Groups', 'Q2-Participated in Clubs', 'Q2-Participated in Halls, JCRCs and/or Residential College CSCs', 'Q2-Participated in University organised events', 'Q2-Participated in Others', 'Q3-Interested in Arts & Culture', 'Q3-Interested in Science & Technology', 'Q3-Interested in Research and independent study', 'Q3-Interested in Sports', 'Q3-Interested in Other competitions (eg case, debates)', 'Q3-Interested in Entrepreneurship', 'Q3-Interested in Volunte
# ...

# %%
# Apply mapping to all categorical columns
for col in categorical_cols:
  df[col] = df[col].map({"Yes": 1,"No": 0})
  df[col] = df[col].fillna(0).astype(int)

# %%
df = df.dropna()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2358 entries, 1 to 2939
# Data columns (total 67 columns):
#  #   Column                                                                                                                      Non-Null Count  Dtype
# ---  ------                                                                                                                      --------------  -----
#  0   Career                                                                                                                      2358 non-null   object
#  1   Citizenship                                                                                                                 2358 non-null   object
#  2   Nationality                                                                                                                 2358 non-null   object
# ...

# %%
df.to_csv('student_survey_cleaned.csv', index=False)
df = pd.read_csv("student_survey_cleaned.csv", encoding="utf-8-sig")
df.head()
# Out:
#   Career      Citizenship Nationality  Year since Matriculation  \
# 0   UGRD  Country Citizen   Singapore                         1
# 1   UGRD        Foreigner    Malaysia                         2
# 2   UGRD        Foreigner    Viet Nam                         3
# 3   UGRD  Country Citizen   Singapore                         1
# 4   UGRD        Foreigner   Indonesia                         3
#
#    Year of Study        Primary Programme Gender             Department  \
# 0              1  Bachelor of Engineering      F  School of Engineering
# 1              2      Bachelor of Science      M      School of Science
# 2              3  Bachelor of Engineering      F  School of Engineering
# 3              1      Bachelor of Science      F      School of Science
# 4              3    Bachelor of Computing      M    School of Computing
#
#            Housing Type  Q1-How many events have you Volunteered in ?  ...  \
# ...
